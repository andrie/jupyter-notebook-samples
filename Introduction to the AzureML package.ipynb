# %% [markdown]
# # Simple example of AzureML

# %%
library(azureml)
sessionInfo()
# Out:
# R version 3.1.3 (2015-03-09)
# Platform: x86_64-w64-mingw32/x64 (64-bit)
# Running under: Windows 8 x64 (build 9200)
#
# locale:
# [1] LC_COLLATE=English_United Kingdom.1252
# [2] LC_CTYPE=English_United Kingdom.1252
# [3] LC_MONETARY=English_United Kingdom.1252
# [4] LC_NUMERIC=C
# [5] LC_TIME=English_United Kingdom.1252
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] azureml_0.0.2
#
# loaded via a namespace (and not attached):
#  [1] base64enc_0.1-2 bitops_1.0-6    digest_0.6.8    evaluate_0.7
#  [5] foreign_0.8-63  httr_1.0.0      IRdisplay_0.3   IRkernel_0.4
#  [9] jsonlite_0.9.15 magrittr_1.5    R6_2.1.1        RCurl_1.95-4.5
# [13] repr_0.3        rzmq_0.7.7      stringi_0.5-5   stringr_1.0.0
# [17] tools_3.1.3     uuid_0.1-2      webapi_0.0.1

# %%
dataset <- "Iris Two Class Data"
#dataset <- "Book Reviews from Amazon"

ws <- workspace()
ds <- datasets(ws)[[dataset]]
frame <- as.data.frame(ds)
print(head(frame))
# Out:
#   Class sepal-length sepal-width petal-length petal-width
# 1     1          6.3         2.9          5.6         1.8
# 2     0          4.8         3.4          1.6         0.2
# 3     1          7.2         3.2          6.0         1.8
# 4     0          5.2         3.4          1.4         0.2
# 5     1          6.7         3.1          5.6         2.4
# 6     0          4.9         3.6          1.4         0.1

# %%
ws <- workspace()
ws

# %%
datasets(ws)
as.list(datasets(ws))
# Out:
# <Workspace>
#   Public:
#     clone: function
#     initialize: function
#
#   Private:
#     authorization.token: eab00da0e3d442ca8dbf7e4713d3a945
#     datasets: environment
#     example.datasets: environment
#     example.experiments: environment
#     experiments: environment
#     id: dd01c7e4a424432c9a9f83142d5cfec4
#     user.datasets: environment
#     user.experiments: environment
# <Datasets>
#   Public:
#     clone: function
#     initialize: function
#
#   Private:
#     add: function
#     create.dataset: function
#     example.filter: NA
#     get.datasets: function
#     get.item: function
#     upload: function
#     workspace: environment
# Error in vapply(seq_along(mapped), function(i) {: values must be length 1,
#  but FUN(X[[14]]) result is length 0
# $Flight_On_Time_Performance_July_October_2013.csv
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$Size
# [1] -1
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=QnPZAxTgQFLLe7E1JGwV6YnQ3FXCptsG9EnykwidOxs%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$Location
# [1] "experimentoutput/8dc9b44e-6c2a-4fd4-b99c-c83df88c563a/185fbba5-2064-4fb7-89ae-ff659eb4b1f8"
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$FileType
# [1] "File"
#
# $Flight_On_Time_Performance_July_October_2013.csv$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$Size
# [1] -1
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=CxuuabxFHRYwEGYM%2BcbNB%2FXCEXtadlC37qiNpMBZofI%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$Location
# [1] "experimentoutput/8dc9b44e-6c2a-4fd4-b99c-c83df88c563a/9b2b80ec-7987-446c-b45c-283671f1b6c2"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$FileType
# [1] "File"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $Flight_On_Time_Performance_July_October_2013.csv$SchemaStatus
# [1] "Complete"
#
# $Flight_On_Time_Performance_July_October_2013.csv$Id
# [1] "dd01c7e4a424432c9a9f83142d5cfec4.a863805e7c514c6f96b17666ef5801e7.v1-default-1"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DataTypeId
# [1] "GenericCSV"
#
# $Flight_On_Time_Performance_July_October_2013.csv$Name
# [1] "Flight_On_Time_Performance_July_October_2013.csv"
#
# $Flight_On_Time_Performance_July_October_2013.csv$Description
# [1] "Flight performance - July to October 2013"
#
# $Flight_On_Time_Performance_July_October_2013.csv$FamilyId
# [1] "a863805e7c514c6f96b17666ef5801e7"
#
# $Flight_On_Time_Performance_July_October_2013.csv$ResourceUploadId
# [1] "6fddcb8c188d420798feefd76a842c16"
#
# $Flight_On_Time_Performance_July_October_2013.csv$SourceOrigin
# [1] "FromResourceUpload"
#
# $Flight_On_Time_Performance_July_October_2013.csv$Size
# [1] 100506313
#
# $Flight_On_Time_Performance_July_October_2013.csv$CreatedDate
# [1] "/Date(1430947497332)/"
#
# $Flight_On_Time_Performance_July_October_2013.csv$Owner
# [1] "apdevries"
#
# $Flight_On_Time_Performance_July_October_2013.csv$ExperimentId
# NULL
#
# $Flight_On_Time_Performance_July_October_2013.csv$ClientVersion
# NULL
#
# $Flight_On_Time_Performance_July_October_2013.csv$PromotedFrom
# NULL
#
# $Flight_On_Time_Performance_July_October_2013.csv$UploadedFromFilename
# [1] "Flight_On_Time_Performance_July_October_2013.csv"
#
# $Flight_On_Time_Performance_July_October_2013.csv$ServiceVersion
# [1] 0
#
# $Flight_On_Time_Performance_July_October_2013.csv$IsLatest
# [1] FALSE
#
# $Flight_On_Time_Performance_July_October_2013.csv$Category
# NULL
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$Size
# [1] -1
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$Name
# [1] "defaultSasName"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=pJwPcol285bS2Nr4ieG1S%2FBaa%2FM8Y9JolC16tctmnDs%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Flight_On_Time_Performance_July_October_2013.csv%22"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$Location
# [1] "uploadedresources/6fddcb8c188d420798feefd76a842c16.csv"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$FileType
# [1] "File"
#
# $Flight_On_Time_Performance_July_October_2013.csv$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $Flight_On_Time_Performance_July_October_2013.csv$IsDeprecated
# [1] FALSE
#
# $Flight_On_Time_Performance_July_October_2013.csv$Culture
# [1] "default"
#
# $Flight_On_Time_Performance_July_October_2013.csv$Batch
# [1] 1
#
# $Flight_On_Time_Performance_July_October_2013.csv$CreatedDateTicks
# [1] 6.356654e+17
#
#
# $TestReadFromBlob
# $TestReadFromBlob$VisualizeEndPoint
# $TestReadFromBlob$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $TestReadFromBlob$VisualizeEndPoint$Size
# [1] -1
#
# $TestReadFromBlob$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $TestReadFromBlob$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $TestReadFromBlob$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $TestReadFromBlob$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=IzY6plwMyrg%2BSGjyfb1qEoHHr86fxfq20b3mUpFkT3g%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $TestReadFromBlob$VisualizeEndPoint$Location
# [1] "experimentoutput/e7d7a745-79f0-45c6-a1a5-5e38e26bcac4/9fadca55-d987-44a2-897c-9cb7b3d85191"
#
# $TestReadFromBlob$VisualizeEndPoint$FileType
# [1] "File"
#
# $TestReadFromBlob$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $TestReadFromBlob$SchemaEndPoint
# $TestReadFromBlob$SchemaEndPoint$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $TestReadFromBlob$SchemaEndPoint$Size
# [1] -1
#
# $TestReadFromBlob$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $TestReadFromBlob$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $TestReadFromBlob$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $TestReadFromBlob$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=QuWu06Y2jb27%2BadYkGuVVL%2FNmk04PBp4whT31Fg3im8%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $TestReadFromBlob$SchemaEndPoint$Location
# [1] "experimentoutput/e7d7a745-79f0-45c6-a1a5-5e38e26bcac4/af0ea0dd-c8dc-48ed-a596-093859168884"
#
# $TestReadFromBlob$SchemaEndPoint$FileType
# [1] "File"
#
# $TestReadFromBlob$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $TestReadFromBlob$SchemaStatus
# [1] "Complete"
#
# $TestReadFromBlob$Id
# [1] "dd01c7e4a424432c9a9f83142d5cfec4.57bcf3a55b73450ea3892a652e0d24b1.v1-default-2"
#
# $TestReadFromBlob$DataTypeId
# [1] "Dataset"
#
# $TestReadFromBlob$Name
# [1] "TestReadFromBlob"
#
# $TestReadFromBlob$Description
# [1] "Used in bootcamp training"
#
# $TestReadFromBlob$FamilyId
# [1] "57bcf3a55b73450ea3892a652e0d24b1"
#
# $TestReadFromBlob$ResourceUploadId
# [1] "6affdff66d1146b98c188db388724d7d"
#
# $TestReadFromBlob$SourceOrigin
# [1] "FromResourceUpload"
#
# $TestReadFromBlob$Size
# [1] 8102
#
# $TestReadFromBlob$CreatedDate
# [1] "/Date(1430947803861)/"
#
# $TestReadFromBlob$Owner
# [1] "apdevries"
#
# $TestReadFromBlob$ExperimentId
# [1] "dd01c7e4a424432c9a9f83142d5cfec4.f-id.73c7d188c13a421b827b1b22f2057890"
#
# $TestReadFromBlob$ClientVersion
# NULL
#
# $TestReadFromBlob$PromotedFrom
# [1] "dd01c7e4a424432c9a9f83142d5cfec4.f-id.73c7d188c13a421b827b1b22f2057890.5d05b2d7-91b5-4a40-8391-41f9b5b21004-83.Results dataset"
#
# $TestReadFromBlob$UploadedFromFilename
# NULL
#
# $TestReadFromBlob$ServiceVersion
# [1] 0
#
# $TestReadFromBlob$IsLatest
# [1] FALSE
#
# $TestReadFromBlob$Category
# NULL
#
# $TestReadFromBlob$DownloadLocation
# $TestReadFromBlob$DownloadLocation$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $TestReadFromBlob$DownloadLocation$Size
# [1] -1
#
# $TestReadFromBlob$DownloadLocation$Name
# [1] "defaultSasName"
#
# $TestReadFromBlob$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $TestReadFromBlob$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $TestReadFromBlob$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=AXq0sKivfJV%2BCTpk4MkFjh47EOjbup%2FX%2FKAotqnAya4%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $TestReadFromBlob$DownloadLocation$Location
# [1] "uploadedresources/6affdff66d1146b98c188db388724d7d.dataset"
#
# $TestReadFromBlob$DownloadLocation$FileType
# [1] "File"
#
# $TestReadFromBlob$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $TestReadFromBlob$IsDeprecated
# [1] FALSE
#
# $TestReadFromBlob$Culture
# [1] "default"
#
# $TestReadFromBlob$Batch
# [1] 2
#
# $TestReadFromBlob$CreatedDateTicks
# [1] 6.356654e+17
#
#
# $`New York weather`
# $`New York weather`$VisualizeEndPoint
# $`New York weather`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $`New York weather`$VisualizeEndPoint$Size
# [1] -1
#
# $`New York weather`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`New York weather`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`New York weather`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`New York weather`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=uAkdzw2t1BxGAvluEpUY3AnyX%2FQXhIt7BC7EWOcGMe0%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`New York weather`$VisualizeEndPoint$Location
# [1] "experimentoutput/340080c9-bd2b-4066-8ff4-c870c2ce0e98/7e738f9b-6ab8-4dd0-b94f-40656dc4340f"
#
# $`New York weather`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`New York weather`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`New York weather`$SchemaEndPoint
# $`New York weather`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $`New York weather`$SchemaEndPoint$Size
# [1] -1
#
# $`New York weather`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`New York weather`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`New York weather`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`New York weather`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=8nq1nLQU54DRhGxJHPfl1mg4TPwOYLrA4Dn8mD6Ph2E%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`New York weather`$SchemaEndPoint$Location
# [1] "experimentoutput/340080c9-bd2b-4066-8ff4-c870c2ce0e98/9210cc27-627a-455b-98e3-48c0c742ccac"
#
# $`New York weather`$SchemaEndPoint$FileType
# [1] "File"
#
# $`New York weather`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`New York weather`$SchemaStatus
# [1] "Complete"
#
# $`New York weather`$Id
# [1] "dd01c7e4a424432c9a9f83142d5cfec4.538c9fd9dafc4128bd41f4659d10aa4f.v1-default-3"
#
# $`New York weather`$DataTypeId
# [1] "GenericCSV"
#
# $`New York weather`$Name
# [1] "New York weather"
#
# $`New York weather`$Description
# [1] "New York weather data.\nSource: http://academic.udayton.edu/kissock/http/Weather/gsod95-current/NYNEWYOR.txt"
#
# $`New York weather`$FamilyId
# [1] "538c9fd9dafc4128bd41f4659d10aa4f"
#
# $`New York weather`$ResourceUploadId
# [1] "f61905fa537f451f9198db6773d32856"
#
# $`New York weather`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`New York weather`$Size
# [1] 116989
#
# $`New York weather`$CreatedDate
# [1] "/Date(1432769052918)/"
#
# $`New York weather`$Owner
# [1] "apdevries"
#
# $`New York weather`$ExperimentId
# NULL
#
# $`New York weather`$ClientVersion
# NULL
#
# $`New York weather`$PromotedFrom
# NULL
#
# $`New York weather`$UploadedFromFilename
# [1] "newyork.csv"
#
# $`New York weather`$ServiceVersion
# [1] 0
#
# $`New York weather`$IsLatest
# [1] FALSE
#
# $`New York weather`$Category
# NULL
#
# $`New York weather`$DownloadLocation
# $`New York weather`$DownloadLocation$BaseUri
# [1] "https://esprodussouthsus.blob.core.windows.net/"
#
# $`New York weather`$DownloadLocation$Size
# [1] -1
#
# $`New York weather`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`New York weather`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`New York weather`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`New York weather`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=b0Ds9F6T8IHZAKUCF5ixYuBAGOkOazaPYgjqxWWXkOQ%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22New%20York%20weather.csv%22"
#
# $`New York weather`$DownloadLocation$Location
# [1] "uploadedresources/f61905fa537f451f9198db6773d32856.csv"
#
# $`New York weather`$DownloadLocation$FileType
# [1] "File"
#
# $`New York weather`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`New York weather`$IsDeprecated
# [1] FALSE
#
# $`New York weather`$Culture
# [1] "default"
#
# $`New York weather`$Batch
# [1] 3
#
# $`New York weather`$CreatedDateTicks
# [1] 6.356837e+17
#
#
# $text.preprocessing.zip
# $text.preprocessing.zip$VisualizeEndPoint
# NULL
#
# $text.preprocessing.zip$SchemaEndPoint
# NULL
#
# $text.preprocessing.zip$SchemaStatus
# [1] "NotSupported"
#
# $text.preprocessing.zip$Id
# [1] "506153734175476c4f62416c57734963.7bbb260f62084435bc0a39d085242d8a.v1-default-653"
#
# $text.preprocessing.zip$DataTypeId
# [1] "Zip"
#
# $text.preprocessing.zip$Name
# [1] "text.preprocessing.zip"
#
# $text.preprocessing.zip$Description
# [1] "Utility R script for text preprocessing to use with text classification template"
#
# $text.preprocessing.zip$FamilyId
# [1] "7bbb260f62084435bc0a39d085242d8a"
#
# $text.preprocessing.zip$ResourceUploadId
# [1] "78f7b04e9c5043b187eb9ace35b660b5"
#
# $text.preprocessing.zip$SourceOrigin
# [1] "FromResourceUpload"
#
# $text.preprocessing.zip$Size
# [1] 2782
#
# $text.preprocessing.zip$CreatedDate
# [1] "/Date(1428532493040)/"
#
# $text.preprocessing.zip$Owner
# [1] "Microsoft Corporation"
#
# $text.preprocessing.zip$ExperimentId
# NULL
#
# $text.preprocessing.zip$ClientVersion
# NULL
#
# $text.preprocessing.zip$PromotedFrom
# NULL
#
# $text.preprocessing.zip$UploadedFromFilename
# NULL
#
# $text.preprocessing.zip$ServiceVersion
# [1] 2
#
# $text.preprocessing.zip$IsLatest
# [1] TRUE
#
# $text.preprocessing.zip$Category
# NULL
#
# $text.preprocessing.zip$DownloadLocation
# $text.preprocessing.zip$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $text.preprocessing.zip$DownloadLocation$Size
# [1] -1
#
# $text.preprocessing.zip$DownloadLocation$Name
# [1] "defaultSasName"
#
# $text.preprocessing.zip$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $text.preprocessing.zip$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $text.preprocessing.zip$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=%2B%2BFTw8UD3KmB3BNWGJRzL5XTzFuRu%2BRBHXAR%2FFtXH2A%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22text.preprocessing.zip%22"
#
# $text.preprocessing.zip$DownloadLocation$Location
# [1] "uploadedresources/78f7b04e9c5043b187eb9ace35b660b5.zip"
#
# $text.preprocessing.zip$DownloadLocation$FileType
# [1] "File"
#
# $text.preprocessing.zip$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $text.preprocessing.zip$IsDeprecated
# [1] FALSE
#
# $text.preprocessing.zip$Culture
# [1] "default"
#
# $text.preprocessing.zip$Batch
# [1] 653
#
# $text.preprocessing.zip$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $fraudTemplateUtil.zip
# $fraudTemplateUtil.zip$VisualizeEndPoint
# NULL
#
# $fraudTemplateUtil.zip$SchemaEndPoint
# NULL
#
# $fraudTemplateUtil.zip$SchemaStatus
# [1] "NotSupported"
#
# $fraudTemplateUtil.zip$Id
# [1] "506153734175476c4f62416c57734963.b915384c130f4afbaf980bc414abcd4a.v1-default-652"
#
# $fraudTemplateUtil.zip$DataTypeId
# [1] "Zip"
#
# $fraudTemplateUtil.zip$Name
# [1] "fraudTemplateUtil.zip"
#
# $fraudTemplateUtil.zip$Description
# [1] "Utility R script to use with online fraud detection template"
#
# $fraudTemplateUtil.zip$FamilyId
# [1] "b915384c130f4afbaf980bc414abcd4a"
#
# $fraudTemplateUtil.zip$ResourceUploadId
# [1] "5359c23499d54371abdc0d53567a6ac3"
#
# $fraudTemplateUtil.zip$SourceOrigin
# [1] "FromResourceUpload"
#
# $fraudTemplateUtil.zip$Size
# [1] 3471
#
# $fraudTemplateUtil.zip$CreatedDate
# [1] "/Date(1428532483377)/"
#
# $fraudTemplateUtil.zip$Owner
# [1] "Microsoft Corporation"
#
# $fraudTemplateUtil.zip$ExperimentId
# NULL
#
# $fraudTemplateUtil.zip$ClientVersion
# NULL
#
# $fraudTemplateUtil.zip$PromotedFrom
# NULL
#
# $fraudTemplateUtil.zip$UploadedFromFilename
# NULL
#
# $fraudTemplateUtil.zip$ServiceVersion
# [1] 2
#
# $fraudTemplateUtil.zip$IsLatest
# [1] TRUE
#
# $fraudTemplateUtil.zip$Category
# NULL
#
# $fraudTemplateUtil.zip$DownloadLocation
# $fraudTemplateUtil.zip$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $fraudTemplateUtil.zip$DownloadLocation$Size
# [1] -1
#
# $fraudTemplateUtil.zip$DownloadLocation$Name
# [1] "defaultSasName"
#
# $fraudTemplateUtil.zip$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $fraudTemplateUtil.zip$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $fraudTemplateUtil.zip$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=hu2XhaaFjlC3JFc6anncVjzHZm6xGn%2BjyGLG374nb5g%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22fraudTemplateUtil.zip%22"
#
# $fraudTemplateUtil.zip$DownloadLocation$Location
# [1] "uploadedresources/5359c23499d54371abdc0d53567a6ac3.zip"
#
# $fraudTemplateUtil.zip$DownloadLocation$FileType
# [1] "File"
#
# $fraudTemplateUtil.zip$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $fraudTemplateUtil.zip$IsDeprecated
# [1] FALSE
#
# $fraudTemplateUtil.zip$Culture
# [1] "default"
#
# $fraudTemplateUtil.zip$Batch
# [1] 652
#
# $fraudTemplateUtil.zip$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`Sample Named Entity Recognition Articles`
# $`Sample Named Entity Recognition Articles`$VisualizeEndPoint
# NULL
#
# $`Sample Named Entity Recognition Articles`$SchemaEndPoint
# NULL
#
# $`Sample Named Entity Recognition Articles`$SchemaStatus
# NULL
#
# $`Sample Named Entity Recognition Articles`$Id
# [1] "506153734175476c4f62416c57734963.16a83d5685e30246840c3187933e07f9.v1-default-358"
#
# $`Sample Named Entity Recognition Articles`$DataTypeId
# [1] "GenericTSVNoHeader"
#
# $`Sample Named Entity Recognition Articles`$Name
# [1] "Sample Named Entity Recognition Articles"
#
# $`Sample Named Entity Recognition Articles`$Description
# [1] "Sample news articles for use with the Named Entity Recognition module"
#
# $`Sample Named Entity Recognition Articles`$FamilyId
# [1] "16a83d5685e30246840c3187933e07f9"
#
# $`Sample Named Entity Recognition Articles`$ResourceUploadId
# [1] "6bfd120a4e7c064a90361c3025023afc"
#
# $`Sample Named Entity Recognition Articles`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Sample Named Entity Recognition Articles`$Size
# [1] 236
#
# $`Sample Named Entity Recognition Articles`$CreatedDate
# [1] "/Date(1405061713264)/"
#
# $`Sample Named Entity Recognition Articles`$Owner
# [1] "Microsoft Corporation"
#
# $`Sample Named Entity Recognition Articles`$ExperimentId
# NULL
#
# $`Sample Named Entity Recognition Articles`$ClientVersion
# NULL
#
# $`Sample Named Entity Recognition Articles`$PromotedFrom
# NULL
#
# $`Sample Named Entity Recognition Articles`$UploadedFromFilename
# NULL
#
# $`Sample Named Entity Recognition Articles`$ServiceVersion
# [1] 8
#
# $`Sample Named Entity Recognition Articles`$IsLatest
# [1] TRUE
#
# $`Sample Named Entity Recognition Articles`$Category
# NULL
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation
# $`Sample Named Entity Recognition Articles`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$Size
# [1] -1
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=2ve60XNlrXE7aFIKqsMaW9VBvCazea3Zz4rbLZnb27Q%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Sample%20Named%20Entity%20Recognition%20Articles.tsv%22"
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$Location
# [1] "uploadedresources/d6fcf372-48a9-4713-82bf-969ecd9006e9/d6fcf372-48a9-4713-82bf-969ecd9006e9.nh.tsv"
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$FileType
# [1] "File"
#
# $`Sample Named Entity Recognition Articles`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Sample Named Entity Recognition Articles`$IsDeprecated
# [1] FALSE
#
# $`Sample Named Entity Recognition Articles`$Culture
# [1] "default"
#
# $`Sample Named Entity Recognition Articles`$Batch
# [1] 358
#
# $`Sample Named Entity Recognition Articles`$CreatedDateTicks
# [1] 6.354066e+17
#
#
# $`Breast cancer data`
# $`Breast cancer data`$VisualizeEndPoint
# $`Breast cancer data`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Breast cancer data`$VisualizeEndPoint$Size
# [1] -1
#
# $`Breast cancer data`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`Breast cancer data`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Breast cancer data`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Breast cancer data`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=Te1Q930RsstKIG0fwIX7Uy%2Bj8%2BrZ1%2B39tk%2FRAIk5RuE%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Breast cancer data`$VisualizeEndPoint$Location
# [1] "experimentoutput/299db9bf-3c87-46c0-9750-43478fe414bb/00d0bf63-2aab-4422-9ac5-abc3152d9f4e"
#
# $`Breast cancer data`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`Breast cancer data`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Breast cancer data`$SchemaEndPoint
# $`Breast cancer data`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Breast cancer data`$SchemaEndPoint$Size
# [1] -1
#
# $`Breast cancer data`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`Breast cancer data`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Breast cancer data`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Breast cancer data`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=W4312PfvlsuGUfD6T3q%2BDCPJmLu5ke%2BEs2hU8GfO31A%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Breast cancer data`$SchemaEndPoint$Location
# [1] "experimentoutput/299db9bf-3c87-46c0-9750-43478fe414bb/4f5d29db-4635-4d42-8324-20f54cdd43d0"
#
# $`Breast cancer data`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Breast cancer data`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Breast cancer data`$SchemaStatus
# [1] "Complete"
#
# $`Breast cancer data`$Id
# [1] "506153734175476c4f62416c57734963.e787101c50d602c8acdc4880e241053e.v1-default-616"
#
# $`Breast cancer data`$DataTypeId
# [1] "ARFF"
#
# $`Breast cancer data`$Name
# [1] "Breast cancer data"
#
# $`Breast cancer data`$Description
# [1] "Breast cancer diagnosis data against features from cell samples"
#
# $`Breast cancer data`$FamilyId
# [1] "e787101c50d602c8acdc4880e241053e"
#
# $`Breast cancer data`$ResourceUploadId
# [1] "3eb064b487a440caaa5d833aae227d36"
#
# $`Breast cancer data`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Breast cancer data`$Size
# [1] 15170
#
# $`Breast cancer data`$CreatedDate
# [1] "/Date(1428530926271)/"
#
# $`Breast cancer data`$Owner
# [1] "Microsoft Corporation"
#
# $`Breast cancer data`$ExperimentId
# NULL
#
# $`Breast cancer data`$ClientVersion
# NULL
#
# $`Breast cancer data`$PromotedFrom
# NULL
#
# $`Breast cancer data`$UploadedFromFilename
# NULL
#
# $`Breast cancer data`$ServiceVersion
# [1] 30
#
# $`Breast cancer data`$IsLatest
# [1] FALSE
#
# $`Breast cancer data`$Category
# NULL
#
# $`Breast cancer data`$DownloadLocation
# $`Breast cancer data`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Breast cancer data`$DownloadLocation$Size
# [1] -1
#
# $`Breast cancer data`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Breast cancer data`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Breast cancer data`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Breast cancer data`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=Q5CwEURgWPfXMtzfcx5hR8c6eeszaYRTTgINehw6s2o%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Breast%20cancer%20data.arff%22"
#
# $`Breast cancer data`$DownloadLocation$Location
# [1] "uploadedresources/3eb064b487a440caaa5d833aae227d36.arff"
#
# $`Breast cancer data`$DownloadLocation$FileType
# [1] "File"
#
# $`Breast cancer data`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Breast cancer data`$IsDeprecated
# [1] FALSE
#
# $`Breast cancer data`$Culture
# [1] "default"
#
# $`Breast cancer data`$Batch
# [1] 616
#
# $`Breast cancer data`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`Forest fires data`
# $`Forest fires data`$VisualizeEndPoint
# $`Forest fires data`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Forest fires data`$VisualizeEndPoint$Size
# [1] -1
#
# $`Forest fires data`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`Forest fires data`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Forest fires data`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Forest fires data`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=B8TZAPY2yOXjLWhQZcluNR2XTxt8iFKbSjNn%2FR6ijYs%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Forest fires data`$VisualizeEndPoint$Location
# [1] "experimentoutput/8e06377f-22e4-437f-9b78-5e52aca31454/f2e77beb-8ff4-4466-8418-cad10d691388"
#
# $`Forest fires data`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`Forest fires data`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Forest fires data`$SchemaEndPoint
# $`Forest fires data`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Forest fires data`$SchemaEndPoint$Size
# [1] -1
#
# $`Forest fires data`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`Forest fires data`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Forest fires data`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Forest fires data`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=6YIIEgdELYFZiG1IYPOQpK16rWuzCfd0ImFlBlQqsU4%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Forest fires data`$SchemaEndPoint$Location
# [1] "experimentoutput/8e06377f-22e4-437f-9b78-5e52aca31454/a0d75060-2ab4-4b55-a651-d6482da24d14"
#
# $`Forest fires data`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Forest fires data`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Forest fires data`$SchemaStatus
# [1] "Complete"
#
# $`Forest fires data`$Id
# [1] "506153734175476c4f62416c57734963.c3dc5bf1d0c60625b30113b61d0c55b6.v1-default-617"
#
# $`Forest fires data`$DataTypeId
# [1] "ARFF"
#
# $`Forest fires data`$Name
# [1] "Forest fires data"
#
# $`Forest fires data`$Description
# [1] "Forest fire sizes in northeast Portugal against weather and other data"
#
# $`Forest fires data`$FamilyId
# [1] "c3dc5bf1d0c60625b30113b61d0c55b6"
#
# $`Forest fires data`$ResourceUploadId
# [1] "1a905abb2500460c9c30e68f47b1c1dc"
#
# $`Forest fires data`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Forest fires data`$Size
# [1] 26285
#
# $`Forest fires data`$CreatedDate
# [1] "/Date(1428530960528)/"
#
# $`Forest fires data`$Owner
# [1] "Microsoft Corporation"
#
# $`Forest fires data`$ExperimentId
# NULL
#
# $`Forest fires data`$ClientVersion
# NULL
#
# $`Forest fires data`$PromotedFrom
# NULL
#
# $`Forest fires data`$UploadedFromFilename
# NULL
#
# $`Forest fires data`$ServiceVersion
# [1] 30
#
# $`Forest fires data`$IsLatest
# [1] FALSE
#
# $`Forest fires data`$Category
# NULL
#
# $`Forest fires data`$DownloadLocation
# $`Forest fires data`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Forest fires data`$DownloadLocation$Size
# [1] -1
#
# $`Forest fires data`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Forest fires data`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Forest fires data`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Forest fires data`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=EB18G1sD%2FekvEjVD2np6tcM7K925SaovH3fK8ENjG3A%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Forest%20fires%20data.arff%22"
#
# $`Forest fires data`$DownloadLocation$Location
# [1] "uploadedresources/1a905abb2500460c9c30e68f47b1c1dc.arff"
#
# $`Forest fires data`$DownloadLocation$FileType
# [1] "File"
#
# $`Forest fires data`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Forest fires data`$IsDeprecated
# [1] FALSE
#
# $`Forest fires data`$Culture
# [1] "default"
#
# $`Forest fires data`$Batch
# [1] 617
#
# $`Forest fires data`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`Iris Two Class Data`
# $`Iris Two Class Data`$VisualizeEndPoint
# $`Iris Two Class Data`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Iris Two Class Data`$VisualizeEndPoint$Size
# [1] -1
#
# $`Iris Two Class Data`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`Iris Two Class Data`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Iris Two Class Data`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Iris Two Class Data`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=4zdsldUvGR92mrO1E0SawRP2CVzm5hEOoSWvcWjl0ig%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Iris Two Class Data`$VisualizeEndPoint$Location
# [1] "experimentoutput/533473f4-9365-4668-a5b0-977b48d281c8/62ffc835-8b2a-46d3-9dfb-d5ac1047d31a"
#
# $`Iris Two Class Data`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`Iris Two Class Data`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Iris Two Class Data`$SchemaEndPoint
# $`Iris Two Class Data`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Iris Two Class Data`$SchemaEndPoint$Size
# [1] -1
#
# $`Iris Two Class Data`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`Iris Two Class Data`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Iris Two Class Data`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Iris Two Class Data`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=flnezKEQYvneWShjjH0JYoIhZo%2BdBTSGmh3Tlx%2BMVDg%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Iris Two Class Data`$SchemaEndPoint$Location
# [1] "experimentoutput/533473f4-9365-4668-a5b0-977b48d281c8/f61fa0b3-18a4-4eb3-8a99-05bc8a0e662a"
#
# $`Iris Two Class Data`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Iris Two Class Data`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Iris Two Class Data`$SchemaStatus
# [1] "Complete"
#
# $`Iris Two Class Data`$Id
# [1] "506153734175476c4f62416c57734963.841ecffabf290c8face9229fc4f9a704.v1-default-618"
#
# $`Iris Two Class Data`$DataTypeId
# [1] "ARFF"
#
# $`Iris Two Class Data`$Name
# [1] "Iris Two Class Data"
#
# $`Iris Two Class Data`$Description
# [1] "Iris Two Class Data"
#
# $`Iris Two Class Data`$FamilyId
# [1] "841ecffabf290c8face9229fc4f9a704"
#
# $`Iris Two Class Data`$ResourceUploadId
# [1] "f0d641ccace340a9ba2d00be4e337034"
#
# $`Iris Two Class Data`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Iris Two Class Data`$Size
# [1] 2004
#
# $`Iris Two Class Data`$CreatedDate
# [1] "/Date(1428530978661)/"
#
# $`Iris Two Class Data`$Owner
# [1] "Microsoft Corporation"
#
# $`Iris Two Class Data`$ExperimentId
# NULL
#
# $`Iris Two Class Data`$ClientVersion
# NULL
#
# $`Iris Two Class Data`$PromotedFrom
# NULL
#
# $`Iris Two Class Data`$UploadedFromFilename
# NULL
#
# $`Iris Two Class Data`$ServiceVersion
# [1] 30
#
# $`Iris Two Class Data`$IsLatest
# [1] FALSE
#
# $`Iris Two Class Data`$Category
# NULL
#
# $`Iris Two Class Data`$DownloadLocation
# $`Iris Two Class Data`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Iris Two Class Data`$DownloadLocation$Size
# [1] -1
#
# $`Iris Two Class Data`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Iris Two Class Data`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Iris Two Class Data`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Iris Two Class Data`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=nD%2F47uVAP%2BjBE2NtIhSEzKCX87LBN4h2FI02mXTL17k%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Iris%20Two%20Class%20Data.arff%22"
#
# $`Iris Two Class Data`$DownloadLocation$Location
# [1] "uploadedresources/f0d641ccace340a9ba2d00be4e337034.arff"
#
# $`Iris Two Class Data`$DownloadLocation$FileType
# [1] "File"
#
# $`Iris Two Class Data`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Iris Two Class Data`$IsDeprecated
# [1] FALSE
#
# $`Iris Two Class Data`$Culture
# [1] "default"
#
# $`Iris Two Class Data`$Batch
# [1] 618
#
# $`Iris Two Class Data`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`Adult Census Income Binary Classification dataset`
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$Size
# [1] -1
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=Xk0tVb6JDRaxWFT9W7OQC1OEv8OneALzHUIMFbsiNLg%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$Location
# [1] "experimentoutput/2612891c-0722-441d-8d04-be6e4ffe2647/a4a0b1a2-57e0-4520-9ac1-503d8198d8a5"
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`Adult Census Income Binary Classification dataset`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$Size
# [1] -1
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=r124wRmK2NJ4HbLmP4iiXjK4VwoUllNCP4WIMoRKv3E%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$Location
# [1] "experimentoutput/2612891c-0722-441d-8d04-be6e4ffe2647/4ecfe6a4-b7ef-4445-a687-a1c5ae44a3c5"
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Adult Census Income Binary Classification dataset`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Adult Census Income Binary Classification dataset`$SchemaStatus
# [1] "Complete"
#
# $`Adult Census Income Binary Classification dataset`$Id
# [1] "506153734175476c4f62416c57734963.72eb09476cd64015b9d1d2129b4a0ecc.v1-default-619"
#
# $`Adult Census Income Binary Classification dataset`$DataTypeId
# [1] "GenericCSV"
#
# $`Adult Census Income Binary Classification dataset`$Name
# [1] "Adult Census Income Binary Classification dataset"
#
# $`Adult Census Income Binary Classification dataset`$Description
# [1] "Census Income dataset"
#
# $`Adult Census Income Binary Classification dataset`$FamilyId
# [1] "72eb09476cd64015b9d1d2129b4a0ecc"
#
# $`Adult Census Income Binary Classification dataset`$ResourceUploadId
# [1] "d4e44bf7a81c4a2a9239f7afc13bf413"
#
# $`Adult Census Income Binary Classification dataset`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Adult Census Income Binary Classification dataset`$Size
# [1] 4007034
#
# $`Adult Census Income Binary Classification dataset`$CreatedDate
# [1] "/Date(1428531005217)/"
#
# $`Adult Census Income Binary Classification dataset`$Owner
# [1] "Microsoft Corporation"
#
# $`Adult Census Income Binary Classification dataset`$ExperimentId
# NULL
#
# $`Adult Census Income Binary Classification dataset`$ClientVersion
# NULL
#
# $`Adult Census Income Binary Classification dataset`$PromotedFrom
# NULL
#
# $`Adult Census Income Binary Classification dataset`$UploadedFromFilename
# NULL
#
# $`Adult Census Income Binary Classification dataset`$ServiceVersion
# [1] 30
#
# $`Adult Census Income Binary Classification dataset`$IsLatest
# [1] FALSE
#
# $`Adult Census Income Binary Classification dataset`$Category
# NULL
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$Size
# [1] -1
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=xHzPXADR7C%2F1m9%2BUlM6gJ3mF2rK%2FImHqlQORKvEoGF0%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Adult%20Census%20Income%20Binary%20Classification%20dataset.csv%22"
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$Location
# [1] "uploadedresources/d4e44bf7a81c4a2a9239f7afc13bf413.csv"
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$FileType
# [1] "File"
#
# $`Adult Census Income Binary Classification dataset`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Adult Census Income Binary Classification dataset`$IsDeprecated
# [1] FALSE
#
# $`Adult Census Income Binary Classification dataset`$Culture
# [1] "default"
#
# $`Adult Census Income Binary Classification dataset`$Batch
# [1] 619
#
# $`Adult Census Income Binary Classification dataset`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`Steel Annealing multi-class dataset`
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$Size
# [1] -1
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=NM4sOrovhNiY%2FU1EVKXU7S1o6iywOrrF952%2FhEACIrM%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$Location
# [1] "experimentoutput/37a6ca34-dd12-4435-9a68-d87af2d7e184/faf81b09-61bd-4a4a-b8ce-b84396a29a49"
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`Steel Annealing multi-class dataset`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$Size
# [1] -1
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=QfBVA2xLN9qubPeCfsUIInr%2BQGWU4I1rhPitCQ%2FLJ3c%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$Location
# [1] "experimentoutput/37a6ca34-dd12-4435-9a68-d87af2d7e184/fa02edce-6c7b-485b-a715-1843947bf307"
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Steel Annealing multi-class dataset`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Steel Annealing multi-class dataset`$SchemaStatus
# [1] "Complete"
#
# $`Steel Annealing multi-class dataset`$Id
# [1] "506153734175476c4f62416c57734963.e84c0c6c4f844a90bd79999e62856f12.v1-default-620"
#
# $`Steel Annealing multi-class dataset`$DataTypeId
# [1] "GenericCSV"
#
# $`Steel Annealing multi-class dataset`$Name
# [1] "Steel Annealing multi-class dataset"
#
# $`Steel Annealing multi-class dataset`$Description
# [1] "Steel annealing data"
#
# $`Steel Annealing multi-class dataset`$FamilyId
# [1] "e84c0c6c4f844a90bd79999e62856f12"
#
# $`Steel Annealing multi-class dataset`$ResourceUploadId
# [1] "01d3d34d32c84b0988a249fdf79e4c71"
#
# $`Steel Annealing multi-class dataset`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Steel Annealing multi-class dataset`$Size
# [1] 81431
#
# $`Steel Annealing multi-class dataset`$CreatedDate
# [1] "/Date(1428531023561)/"
#
# $`Steel Annealing multi-class dataset`$Owner
# [1] "Microsoft Corporation"
#
# $`Steel Annealing multi-class dataset`$ExperimentId
# NULL
#
# $`Steel Annealing multi-class dataset`$ClientVersion
# NULL
#
# $`Steel Annealing multi-class dataset`$PromotedFrom
# NULL
#
# $`Steel Annealing multi-class dataset`$UploadedFromFilename
# NULL
#
# $`Steel Annealing multi-class dataset`$ServiceVersion
# [1] 30
#
# $`Steel Annealing multi-class dataset`$IsLatest
# [1] FALSE
#
# $`Steel Annealing multi-class dataset`$Category
# NULL
#
# $`Steel Annealing multi-class dataset`$DownloadLocation
# $`Steel Annealing multi-class dataset`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$Size
# [1] -1
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=NCZnjUSmJyHUJrbPxkGyI3UFzKC%2BdBeNHo%2BNB06dPys%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Steel%20Annealing%20multi-class%20dataset.csv%22"
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$Location
# [1] "uploadedresources/01d3d34d32c84b0988a249fdf79e4c71.csv"
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$FileType
# [1] "File"
#
# $`Steel Annealing multi-class dataset`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Steel Annealing multi-class dataset`$IsDeprecated
# [1] FALSE
#
# $`Steel Annealing multi-class dataset`$Culture
# [1] "default"
#
# $`Steel Annealing multi-class dataset`$Batch
# [1] 620
#
# $`Steel Annealing multi-class dataset`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`Automobile price data (Raw)`
# $`Automobile price data (Raw)`$VisualizeEndPoint
# $`Automobile price data (Raw)`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$Size
# [1] -1
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=6EpP%2FLDaReXwqRQ3310YD02Al%2Fg8NkmZr0phI8obsl0%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$Location
# [1] "experimentoutput/84cafa87-2a05-439b-9324-118d43cfa494/75ad77f5-91be-4ee0-b707-d85fce1415bb"
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`Automobile price data (Raw)`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Automobile price data (Raw)`$SchemaEndPoint
# $`Automobile price data (Raw)`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Automobile price data (Raw)`$SchemaEndPoint$Size
# [1] -1
#
# $`Automobile price data (Raw)`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`Automobile price data (Raw)`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Automobile price data (Raw)`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Automobile price data (Raw)`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=VFiGJWzepYZbT6M5sgrthtmBL8jChxFQS0TnTU4bU7U%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Automobile price data (Raw)`$SchemaEndPoint$Location
# [1] "experimentoutput/84cafa87-2a05-439b-9324-118d43cfa494/f37d9976-2b32-4f92-aa2e-5c36335d73fb"
#
# $`Automobile price data (Raw)`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Automobile price data (Raw)`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Automobile price data (Raw)`$SchemaStatus
# [1] "Complete"
#
# $`Automobile price data (Raw)`$Id
# [1] "506153734175476c4f62416c57734963.053d815bac1b07d6b6c50646456107d4.v1-default-621"
#
# $`Automobile price data (Raw)`$DataTypeId
# [1] "GenericCSV"
#
# $`Automobile price data (Raw)`$Name
# [1] "Automobile price data (Raw)"
#
# $`Automobile price data (Raw)`$Description
# [1] "Missing Value Scrubber module required. Prices of various automobiles against make, model and technical specifications"
#
# $`Automobile price data (Raw)`$FamilyId
# [1] "053d815bac1b07d6b6c50646456107d4"
#
# $`Automobile price data (Raw)`$ResourceUploadId
# [1] "c53f8230baef4d488fa7bb790fe28fcd"
#
# $`Automobile price data (Raw)`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Automobile price data (Raw)`$Size
# [1] 26420
#
# $`Automobile price data (Raw)`$CreatedDate
# [1] "/Date(1428531042209)/"
#
# $`Automobile price data (Raw)`$Owner
# [1] "Microsoft Corporation"
#
# $`Automobile price data (Raw)`$ExperimentId
# NULL
#
# $`Automobile price data (Raw)`$ClientVersion
# NULL
#
# $`Automobile price data (Raw)`$PromotedFrom
# NULL
#
# $`Automobile price data (Raw)`$UploadedFromFilename
# NULL
#
# $`Automobile price data (Raw)`$ServiceVersion
# [1] 30
#
# $`Automobile price data (Raw)`$IsLatest
# [1] FALSE
#
# $`Automobile price data (Raw)`$Category
# NULL
#
# $`Automobile price data (Raw)`$DownloadLocation
# $`Automobile price data (Raw)`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Automobile price data (Raw)`$DownloadLocation$Size
# [1] -1
#
# $`Automobile price data (Raw)`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Automobile price data (Raw)`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Automobile price data (Raw)`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Automobile price data (Raw)`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=z5hCqOgcip4WBxTJ43uaD0ge9V37f%2FkDyCcUJAAsDjc%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Automobile%20price%20data%20_Raw_.csv%22"
#
# $`Automobile price data (Raw)`$DownloadLocation$Location
# [1] "uploadedresources/c53f8230baef4d488fa7bb790fe28fcd.csv"
#
# $`Automobile price data (Raw)`$DownloadLocation$FileType
# [1] "File"
#
# $`Automobile price data (Raw)`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Automobile price data (Raw)`$IsDeprecated
# [1] FALSE
#
# $`Automobile price data (Raw)`$Culture
# [1] "default"
#
# $`Automobile price data (Raw)`$Batch
# [1] 621
#
# $`Automobile price data (Raw)`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`MPG data for various automobiles`
# $`MPG data for various automobiles`$VisualizeEndPoint
# $`MPG data for various automobiles`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`MPG data for various automobiles`$VisualizeEndPoint$Size
# [1] -1
#
# ...
#
# $`Named Entity Recognition Sample Articles`$SchemaEndPoint$Location
# [1] "experimentoutput/317f6d49-9ac4-4d31-90bb-6dc08adadb53/ca3a3103-55e3-456b-a108-fe803aa164ca"
#
# $`Named Entity Recognition Sample Articles`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Named Entity Recognition Sample Articles`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Named Entity Recognition Sample Articles`$SchemaStatus
# [1] "Complete"
#
# $`Named Entity Recognition Sample Articles`$Id
# [1] "506153734175476c4f62416c57734963.6dee1fc8d44141c9ad41e46ad94b85b3.v1-default-648"
#
# $`Named Entity Recognition Sample Articles`$DataTypeId
# [1] "GenericTSVNoHeader"
#
# $`Named Entity Recognition Sample Articles`$Name
# [1] "Named Entity Recognition Sample Articles"
#
# $`Named Entity Recognition Sample Articles`$Description
# [1] "Named Entity Recognition Sample Articles"
#
# $`Named Entity Recognition Sample Articles`$FamilyId
# [1] "6dee1fc8d44141c9ad41e46ad94b85b3"
#
# $`Named Entity Recognition Sample Articles`$ResourceUploadId
# [1] "45198e52d4c04ec8994cbfc1d8b787ab"
#
# $`Named Entity Recognition Sample Articles`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Named Entity Recognition Sample Articles`$Size
# [1] 236
#
# $`Named Entity Recognition Sample Articles`$CreatedDate
# [1] "/Date(1428532197539)/"
#
# $`Named Entity Recognition Sample Articles`$Owner
# [1] "Microsoft Corporation"
#
# $`Named Entity Recognition Sample Articles`$ExperimentId
# NULL
#
# $`Named Entity Recognition Sample Articles`$ClientVersion
# NULL
#
# $`Named Entity Recognition Sample Articles`$PromotedFrom
# NULL
#
# $`Named Entity Recognition Sample Articles`$UploadedFromFilename
# NULL
#
# $`Named Entity Recognition Sample Articles`$ServiceVersion
# [1] 7
#
# $`Named Entity Recognition Sample Articles`$IsLatest
# [1] FALSE
#
# $`Named Entity Recognition Sample Articles`$Category
# NULL
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation
# $`Named Entity Recognition Sample Articles`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$Size
# [1] -1
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=S9ma7qs92ea72G5%2FarzVB7gkgkvqoQpLo6vxichk1bE%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Named%20Entity%20Recognition%20Sample%20Articles.tsv%22"
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$Location
# [1] "uploadedresources/45198e52d4c04ec8994cbfc1d8b787ab.nh.tsv"
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$FileType
# [1] "File"
#
# $`Named Entity Recognition Sample Articles`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Named Entity Recognition Sample Articles`$IsDeprecated
# [1] FALSE
#
# $`Named Entity Recognition Sample Articles`$Culture
# [1] "default"
#
# $`Named Entity Recognition Sample Articles`$Batch
# [1] 648
#
# $`Named Entity Recognition Sample Articles`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`Book Reviews from Amazon`
# $`Book Reviews from Amazon`$VisualizeEndPoint
# $`Book Reviews from Amazon`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$Size
# [1] -1
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=9c%2BoQZtTyKYEBqLcTIh%2B7xYJyBZMVECp2xU70gTWAOw%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$Location
# [1] "experimentoutput/ba6ebae7-83a4-4184-824a-85f0649ce2fe/f57d02fc-9e97-439f-aebf-4a2686a285e7"
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`Book Reviews from Amazon`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Book Reviews from Amazon`$SchemaEndPoint
# $`Book Reviews from Amazon`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Book Reviews from Amazon`$SchemaEndPoint$Size
# [1] -1
#
# $`Book Reviews from Amazon`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`Book Reviews from Amazon`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`Book Reviews from Amazon`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`Book Reviews from Amazon`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=nvQoJIShHLd%2Fl764OCdz9X0TWFEW9tFo%2FLddJoKrYQM%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`Book Reviews from Amazon`$SchemaEndPoint$Location
# [1] "experimentoutput/ba6ebae7-83a4-4184-824a-85f0649ce2fe/04fe629b-b14b-42f7-baf1-eda8eb819d3b"
#
# $`Book Reviews from Amazon`$SchemaEndPoint$FileType
# [1] "File"
#
# $`Book Reviews from Amazon`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`Book Reviews from Amazon`$SchemaStatus
# [1] "Complete"
#
# $`Book Reviews from Amazon`$Id
# [1] "506153734175476c4f62416c57734963.0c5234182a844ce4a201bb9ad6739cf6.v1-default-649"
#
# $`Book Reviews from Amazon`$DataTypeId
# [1] "GenericTSVNoHeader"
#
# $`Book Reviews from Amazon`$Name
# [1] "Book Reviews from Amazon"
#
# $`Book Reviews from Amazon`$Description
# [1] "Book Reviews from Amazon"
#
# $`Book Reviews from Amazon`$FamilyId
# [1] "0c5234182a844ce4a201bb9ad6739cf6"
#
# $`Book Reviews from Amazon`$ResourceUploadId
# [1] "34f026ae83614cecb24789ae326d985d"
#
# $`Book Reviews from Amazon`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`Book Reviews from Amazon`$Size
# [1] 9725944
#
# $`Book Reviews from Amazon`$CreatedDate
# [1] "/Date(1428532227702)/"
#
# $`Book Reviews from Amazon`$Owner
# [1] "Microsoft Corporation"
#
# $`Book Reviews from Amazon`$ExperimentId
# NULL
#
# $`Book Reviews from Amazon`$ClientVersion
# NULL
#
# $`Book Reviews from Amazon`$PromotedFrom
# NULL
#
# $`Book Reviews from Amazon`$UploadedFromFilename
# NULL
#
# $`Book Reviews from Amazon`$ServiceVersion
# [1] 7
#
# $`Book Reviews from Amazon`$IsLatest
# [1] FALSE
#
# $`Book Reviews from Amazon`$Category
# NULL
#
# $`Book Reviews from Amazon`$DownloadLocation
# $`Book Reviews from Amazon`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`Book Reviews from Amazon`$DownloadLocation$Size
# [1] -1
#
# $`Book Reviews from Amazon`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`Book Reviews from Amazon`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`Book Reviews from Amazon`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`Book Reviews from Amazon`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=Va6U2uZLjPt3zyfYvDM8FiaVo1li5vPK7CSFWgGD6Oc%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22Book%20Reviews%20from%20Amazon.tsv%22"
#
# $`Book Reviews from Amazon`$DownloadLocation$Location
# [1] "uploadedresources/34f026ae83614cecb24789ae326d985d.nh.tsv"
#
# $`Book Reviews from Amazon`$DownloadLocation$FileType
# [1] "File"
#
# $`Book Reviews from Amazon`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`Book Reviews from Amazon`$IsDeprecated
# [1] FALSE
#
# $`Book Reviews from Amazon`$Culture
# [1] "default"
#
# $`Book Reviews from Amazon`$Batch
# [1] 649
#
# $`Book Reviews from Amazon`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`MNIST Test 10k 28x28 dense`
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$Size
# [1] -1
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=rJSGLEwiJKXytvNUBgmIbwzG1QjM3hW311NrUAoipoA%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$Location
# [1] "experimentoutput/45805143-6275-47ff-9d97-af13bfa28db5/99c3d2ba-e481-4296-8e4b-2f0df06fe9ad"
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`MNIST Test 10k 28x28 dense`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$Size
# [1] -1
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=BDjZkslXHAqBucWGKLBtkahSYr6autaQwcFT1eQYkzM%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$Location
# [1] "experimentoutput/45805143-6275-47ff-9d97-af13bfa28db5/91627f65-0028-4019-a9e5-d312c3e28f28"
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$FileType
# [1] "File"
#
# $`MNIST Test 10k 28x28 dense`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`MNIST Test 10k 28x28 dense`$SchemaStatus
# [1] "Complete"
#
# $`MNIST Test 10k 28x28 dense`$Id
# [1] "506153734175476c4f62416c57734963.896db14734324ce084481451363389f8.v1-default-650"
#
# $`MNIST Test 10k 28x28 dense`$DataTypeId
# [1] "GenericTSV"
#
# $`MNIST Test 10k 28x28 dense`$Name
# [1] "MNIST Test 10k 28x28 dense"
#
# $`MNIST Test 10k 28x28 dense`$Description
# [1] "MNIST Test data"
#
# $`MNIST Test 10k 28x28 dense`$FamilyId
# [1] "896db14734324ce084481451363389f8"
#
# $`MNIST Test 10k 28x28 dense`$ResourceUploadId
# [1] "1acb85770ede4bc3ac35d30b7a7fbcef"
#
# $`MNIST Test 10k 28x28 dense`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`MNIST Test 10k 28x28 dense`$Size
# [1] 18303260
#
# $`MNIST Test 10k 28x28 dense`$CreatedDate
# [1] "/Date(1428532280774)/"
#
# $`MNIST Test 10k 28x28 dense`$Owner
# [1] "Microsoft Corporation"
#
# $`MNIST Test 10k 28x28 dense`$ExperimentId
# NULL
#
# $`MNIST Test 10k 28x28 dense`$ClientVersion
# NULL
#
# $`MNIST Test 10k 28x28 dense`$PromotedFrom
# NULL
#
# $`MNIST Test 10k 28x28 dense`$UploadedFromFilename
# NULL
#
# $`MNIST Test 10k 28x28 dense`$ServiceVersion
# [1] 2
#
# $`MNIST Test 10k 28x28 dense`$IsLatest
# [1] FALSE
#
# $`MNIST Test 10k 28x28 dense`$Category
# NULL
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$Size
# [1] -1
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=tIr6sy3FEztzmegvNDjj3Q6szgxtjRESAcvMqQtjbgM%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22MNIST%20Test%2010k%2028x28%20dense.tsv%22"
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$Location
# [1] "uploadedresources/1acb85770ede4bc3ac35d30b7a7fbcef.tsv"
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$FileType
# [1] "File"
#
# $`MNIST Test 10k 28x28 dense`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`MNIST Test 10k 28x28 dense`$IsDeprecated
# [1] FALSE
#
# $`MNIST Test 10k 28x28 dense`$Culture
# [1] "default"
#
# $`MNIST Test 10k 28x28 dense`$Batch
# [1] 650
#
# $`MNIST Test 10k 28x28 dense`$CreatedDateTicks
# [1] 6.356413e+17
#
#
# $`MNIST Train 60k 28x28 dense`
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$Size
# [1] -1
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$Name
# [1] "defaultSasName"
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$CredentialContainer
# [1] "Inline"
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=H1LFne14S8Y2mKnjASUQJ8w9%2Bvem3gkIGY5kyEk89%2Fs%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$Location
# [1] "experimentoutput/accd3ab6-d9f9-4cdb-9f0c-1db96b8f7cd6/19977d2b-6956-4a5d-aeee-2eb7fbadbb6f"
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$FileType
# [1] "File"
#
# $`MNIST Train 60k 28x28 dense`$VisualizeEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$Size
# [1] -1
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$Name
# [1] "defaultSasName"
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$EndpointType
# [1] "SasEndpoint"
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$CredentialContainer
# [1] "Inline"
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=k6t6KnuAHFubpfscoI2Abkfw5N%2FZlLmNXQXx%2BnlYAEM%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r"
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$Location
# [1] "experimentoutput/accd3ab6-d9f9-4cdb-9f0c-1db96b8f7cd6/14bbb786-c133-4efa-a747-19d7e2aa365b"
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$FileType
# [1] "File"
#
# $`MNIST Train 60k 28x28 dense`$SchemaEndPoint$IsAuxiliary
# [1] FALSE
#
#
# $`MNIST Train 60k 28x28 dense`$SchemaStatus
# [1] "Complete"
#
# $`MNIST Train 60k 28x28 dense`$Id
# [1] "506153734175476c4f62416c57734963.100b00d330fb44d3a80f3aac3c15b5ac.v1-default-651"
#
# $`MNIST Train 60k 28x28 dense`$DataTypeId
# [1] "GenericTSV"
#
# $`MNIST Train 60k 28x28 dense`$Name
# [1] "MNIST Train 60k 28x28 dense"
#
# $`MNIST Train 60k 28x28 dense`$Description
# [1] "MNIST Training data"
#
# $`MNIST Train 60k 28x28 dense`$FamilyId
# [1] "100b00d330fb44d3a80f3aac3c15b5ac"
#
# $`MNIST Train 60k 28x28 dense`$ResourceUploadId
# [1] "bbeef1e840314433bc30d292854c1041"
#
# $`MNIST Train 60k 28x28 dense`$SourceOrigin
# [1] "FromResourceUpload"
#
# $`MNIST Train 60k 28x28 dense`$Size
# [1] 109639811
#
# $`MNIST Train 60k 28x28 dense`$CreatedDate
# [1] "/Date(1428532408027)/"
#
# $`MNIST Train 60k 28x28 dense`$Owner
# [1] "Microsoft Corporation"
#
# $`MNIST Train 60k 28x28 dense`$ExperimentId
# NULL
#
# $`MNIST Train 60k 28x28 dense`$ClientVersion
# NULL
#
# $`MNIST Train 60k 28x28 dense`$PromotedFrom
# NULL
#
# $`MNIST Train 60k 28x28 dense`$UploadedFromFilename
# NULL
#
# $`MNIST Train 60k 28x28 dense`$ServiceVersion
# [1] 2
#
# $`MNIST Train 60k 28x28 dense`$IsLatest
# [1] FALSE
#
# $`MNIST Train 60k 28x28 dense`$Category
# NULL
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$BaseUri
# [1] "https://esprodussouth001.blob.core.windows.net/"
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$Size
# [1] -1
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$Name
# [1] "defaultSasName"
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$EndpointType
# [1] "SasEndpoint"
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$CredentialContainer
# [1] "Inline"
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$AccessCredential
# [1] "?sv=2013-08-15&sr=b&sig=9c8Li1IzYFnIgIpDKUtJKSJTTUInBI70NmiNg3eQ4%2F8%3D&st=2015-10-04T08%3A50%3A02Z&se=2015-10-05T08%3A55%3A02Z&sp=r&rscd=attachment%3B%20filename%3D%22MNIST%20Train%2060k%2028x28%20dense.tsv%22"
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$Location
# [1] "uploadedresources/bbeef1e840314433bc30d292854c1041.tsv"
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$FileType
# [1] "File"
#
# $`MNIST Train 60k 28x28 dense`$DownloadLocation$IsAuxiliary
# [1] FALSE
#
#
# $`MNIST Train 60k 28x28 dense`$IsDeprecated
# [1] FALSE
#
# $`MNIST Train 60k 28x28 dense`$Culture
# [1] "default"
#
# $`MNIST Train 60k 28x28 dense`$Batch
# [1] 651
#
# $`MNIST Train 60k 28x28 dense`$CreatedDateTicks
# [1] 6.356413e+17

# %% [markdown]
# ---
# Created by a Microsoft Employee.
# Copyright (C) Microsoft. All Rights Reserved.
